# %% [markdown]
# # Test GEModelTools - HANK

# %% [markdown]
# This notebook shows how to **solve a simple Heterogenous Agent New Keynessian (HANK) model** using the `GEModelTools` package.
#
# **The steps of the sequence-space solution method are:**
#
# 1. Find the stationary equilibrium (steady state for aggregates and distribution).
# 2. Compute Jacobians of the household block and the full model (to unknowns and shocks)
# 3. Find the non-linear transition path or the linearized impulse responses to a given shock path.
# 4. Simulate the linearized model with aggregate risk

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from HANKmodel import HANKModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Setup

# %%
model = HANKModelClass(name='baseline')

# %% [markdown]
# # Step 1: Steady state

# %%
model.find_ss(do_print=True)
# Out:
# ### step 1: broad search ###
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# invalid index to scalar variable.
# clearing_AB =          nan
#
# ### step 2: determine search bracket ###
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Signe\OneDrive - University of Copenhagen\Documents\Speciale\kode\hank-speciale\one_sector\HANK.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Signe/OneDrive%20-%20University%20of%20Copenhagen/Documents/Speciale/kode/hank-speciale/one_sector/HANK.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> model.find_ss(do_print=True)
#
# File c:\Users\Signe\OneDrive - University of Copenhagen\Documents\Speciale\kode\hank-speciale\one_sector\steady_state.py:127, in find_ss_direct(model, do_print, M_min, M_max, NK)
#     124 # b. determine search bracket
#     125 if do_print: print(f'### step 2: determine search bracket ###\n')
# --> 127 M_max = np.min(M_ss_vec[clearing_AB < 0])
#     128 M_min = np.max(M_ss_vec[clearing_AB > 0])
#     130 if do_print: print(f'M in [{M_min:12.8f},{M_max:12.8f}]\n')
#
# File <__array_function__ internals>:5, in amin(*args, **kwargs)
#
# File c:\Users\Signe\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2879, in amin(a, axis, out, keepdims, initial, where)
#    2763 @array_function_dispatch(_amin_dispatcher)
#    2764 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2765          where=np._NoValue):
#    2766     """
#    2767     Return the minimum of an array or minimum along an axis.
#    2768
#    (...)
#    2877     6
#    2878     """
# -> 2879     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2880                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\Signe\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
par = model.par
ss = model.ss
path = model.path
sim = model.sim

# %% [markdown]
# ## Policy functions

# %%
fig = plt.figure(figsize=(18,4),dpi=100)
a_max = 500

# a. consumption
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,1)
ax.set_title(f'consumption')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.c[0,i_z,I],label=f'i_z = {i_z}')

ax.legend(frameon=True)
ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('consumption, $c_t$')

# b. saving
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,2)
ax.set_title(f'saving')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.a[0,i_z,I],label=f'i_z = {i_z}')

ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('savings, $a_{t}$')

# c. labor supply
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,3)
ax.set_title(f'labor_supply')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.ell[0,i_z,I],label=f'i_z = {i_z}')

ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('labor supply, $n_{t}$')

fig.tight_layout()

# %% [markdown]
# ## Simulation

# %%
fig = plt.figure(figsize=(12,4),dpi=100)

# a. income
ax = fig.add_subplot(1,2,1)
ax.set_title('productivity')

y = np.cumsum(np.sum(ss.D[0],axis=1))
ax.plot(par.z_grid,y/y[-1])

ax.set_xlabel('productivity, $z_{t}$')
ax.set_ylabel('CDF')

# b. assets
ax = fig.add_subplot(1,2,2)
ax.set_title('savings')
y = np.insert(np.cumsum(np.sum(ss.D[0],axis=0)),0,0.0)
ax.plot(np.insert(par.a_grid,0,par.a_grid[0]),y/y[-1])
        
ax.set_xlabel('assets, $a_{t}$')
ax.set_ylabel('CDF')
ax.set_xscale('symlog')

# %% [markdown]
# # Step 2: Compute Jacobians (incl. tests)

# %% [markdown]
# **Household transition path:**

# %%
model.test_hh_path()
# Out:
# note: inputs = steady state value -> expected: constant value (straigt line)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Signe\OneDrive - University of Copenhagen\Documents\Speciale\kode\hank-speciale\HANK.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Signe/OneDrive%20-%20University%20of%20Copenhagen/Documents/Speciale/kode/hank-speciale/HANK.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> model.test_hh_path()
#
# File c:\users\signe\onedrive - university of copenhagen\documents\speciale\gemodeltools\GEModelTools\tests.py:49, in hh_path(model)
#      47 # a. solution and simulation hh along path
#      48 model._set_inputs_hh_all_ss()
# ---> 49 model.solve_hh_path(do_print=True)
#      50 model.simulate_hh_path(do_print=True)
#      53 # b. show mean of each hh output
#
# File c:\users\signe\onedrive - university of copenhagen\documents\speciale\gemodeltools\GEModelTools\GEModelClass.py:466, in GEModelClass.solve_hh_path(self, do_print)
#     463             path.z_trans[t,:] = ss.z_trans
#     465         # ii. stepbacks
# --> 466         stepvars_hh = self._get_stepvars_hh_path(t)
#     467         self.solve_hh_backwards(**stepvars_hh)
#     469 # c. indices and weights
#
# File c:\users\signe\onedrive - university of copenhagen\documents\speciale\gemodeltools\GEModelTools\GEModelClass.py:430, in GEModelClass._get_stepvars_hh_path(self, t)
#     427 ss = self.ss
#     429 stepvars_hh = {'par':par,'z_trans':path.z_trans[t]}
# --> 430 for varname in self.inputs_hh: stepvars_hh[varname] = getattr(path,varname)[0,t]
#     431 for varname in self.outputs_hh + self.intertemps_hh: stepvars_hh[varname] = getattr(path,f'{varname}')[t]
#     433 for varname in self.intertemps_hh:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# **Full transition path:**

# %%
model.test_path()

# %%
model.test_jacs(s_list=[50,100,150])

# %% [markdown]
# # Step 3a: Find non-linear transition path

# %% [markdown]
# ## Find transition path

# %%
par.jump_istar = -0.10/4
model.find_transition_path(do_print=True)

# %% [markdown]
# ## Plot transitions

# %%
paths = ['i','pi','r','C']
lvl_value = ['i','pi','r']
model.show_IRFs(paths,lvl_value=lvl_value,T_max=20,ncols=3)

# %% [markdown]
# # Step 3b: Find linearized IRFs

# %%
model.find_IRFs(do_print=True)

# %%
paths = ['C']
model.show_IRFs(paths,T_max=20,ncols=3,do_linear=True)

# %% [markdown]
# # Step 4. Simulation

# %%
np.random.seed(1917)
model.simulate(do_print=True)

# %%
def model_sim():
    
    fig = plt.figure(figsize=(12,8),dpi=100)

    ax = fig.add_subplot(2,2,1)
    ax.set_title('i')
    ax.plot(ss.i+sim.di,ls='--')
    ax.axhline(ss.i,color='black',zorder=0)

    ax = fig.add_subplot(2,2,2)
    ax.set_title('pi')
    ax.plot(ss.pi+sim.dpi,ls='--',)
    ax.axhline(ss.pi,color='black',zorder=0)
    
    ax = fig.add_subplot(2,2,3)
    ax.set_title('r')
    ax.plot(ss.r+sim.dr,ls='--',)
    ax.axhline(ss.r,color='black',zorder=0)
    
    ax = fig.add_subplot(2,2,4)
    ax.set_title('C')
    ax.plot(ss.C+sim.dC,ls='--',)
    ax.axhline(ss.C,color='black',zorder=0)

# %%
model_sim()
